# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusgomesbatista/pythonintermediario/blob/main/tipos%20de%20an%C3%A1lise/Notebook_Python%20_Aula1_2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar as bibliotecas
import pandas as pd # para trabalhar com dataframes
import seaborn as sns # para visualização de dados / gráficos
import matplotlib.pyplot as plt # para visualização de dados / gráficos

# %%
# acessar os dados em um dataframe
df = sns.load_dataset(name='penguins')

# %% [markdown]
# # Análise exploratória

# %%
#visualizando as 5 primeiras linhas
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# visualizando a 5 últimas linhas
df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
display(df)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# ver as colunas
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# ver a estrutura dos dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# resumo estatístico
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# resumo das variáveis do tipo object
df.describe(include='O')
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       152     168   168

# %%
# quantidade valores únicos
df.nunique()
# Out:
# species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# dtype: int64

# %%
# valores únicos de uma determina coluna/variável
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
# valores únicos de uma determina coluna/variável
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# # Análise Descritiva

# %% [markdown]
# ### Buscar padrões e tendências

# %%
# Peso médio dos pinguins
round(df['body_mass_g'].mean(),2)
# Out:
# 4201.75

# %%
# Peso mínimo dos pinguins
df['body_mass_g'].min()
# Out:
# 2700.0

# %%
# Peso máximo dos pinguins
df['body_mass_g'].max()
# Out:
# 6300.0

# %%
# gráfico de quantidade de pinguins por espécie
sns.countplot(x=df['species'])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# gráfico de quantidade de pinguins por ilha
sns.countplot(x=df['island'])
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
# gráfico de quantidade de pinguins por ilha
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# gráfico de quantidade de pinguins por ilha e sexo
sns.countplot(x='island', hue='sex', data=df)
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
# gráfico de quantidade de pinguins por espécie e sexo
sns.countplot(x='species', hue='sex', data=df)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# gráfico de peso médio dos pinguins por espécie
sns.barplot(x='species', y='body_mass_g', data=df)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
df['body_mass_g'].describe()
# Out:
# count     342.000000
# mean     4201.754386
# std       801.954536
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4750.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
# Visualizar a distribuição da massa corporal dos pinguis por espécie utilizando BoxPlot
plt.figure(figsize=(6,6))
sns.boxplot(y='body_mass_g', data=df)
plt.show()

# %%
sns.histplot(x='body_mass_g', data=df, bins=100)  # Você pode ajustar o número de bins conforme necessário
plt.show()

# %%
sns.violinplot(x='body_mass_g', data=df)
plt.show()

# %%
# Visualizar a distribuição da massa corporal dos pinguis por espécie utilizando BoxPlot
plt.figure(figsize=(6,6))
sns.boxplot(y='body_mass_g',x='sex', data=df)
plt.show()

# %%
# Visualizar a distribuição da massa corporal dos pinguis por espécie utilizando BoxPlot
plt.figure(figsize=(6,6))
sns.boxplot(y='body_mass_g',x='species', data=df)
plt.show()

# %%
# Visualizar a distribuição da massa corporal dos pinguis por espécie utilizando BoxPlot
plt.figure(figsize=(6,6))
sns.boxplot(y='body_mass_g',x='island', data=df)
plt.show()

# %%
# Criar subplots
plt.figure(figsize=(6,6))
sns.boxplot(y='body_mass_g',x='species', hue='sex', data=df)
plt.show()

# %%
# Criar subplots
plt.figure(figsize=(6,6))
sns.boxplot(y='body_mass_g',x='island', hue='species', data=df)
plt.show()

# %%
# Criar subplots
plt.figure(figsize=(6,6))
sns.boxplot(y='body_mass_g',x='species', hue='island', data=df)
plt.show()

# %%
# Criando subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 12), constrained_layout=True) #criando o subplot

# Gráficos de caixa para diferentes variáveis dos pinguins
sns.boxplot(x='species', y='bill_length_mm', hue='sex', data=df, orient='v', ax=axs[0][0])
sns.boxplot(x='species', y='bill_depth_mm', hue='sex', data=df, orient='v', ax=axs[0][1])
sns.boxplot(x='species', y='flipper_length_mm', hue='sex', data=df, orient='v', ax=axs[1][0])
sns.boxplot(x='species', y='body_mass_g', hue='sex', data=df, orient='v', ax=axs[1][1])

# Exibindo os subplots
plt.show()

# %%
# gráficos de dispersão analisando tamanho do bico e altura do bico
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', data=df)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# gráficos de dispersão analisando tamanho do bico e altura do bico por espécie
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', hue='species', data=df)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# gráficos de dispersão analisando peso e tamanho da nadadeira
sns.scatterplot(x='body_mass_g', y='flipper_length_mm', data=df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# gráficos de dispersão analisando peso e tamanho da nadadeira por espécie
sns.scatterplot(x='body_mass_g', y='flipper_length_mm',hue='species', data=df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# Testar relação (scatterplot / gráfico de dispersão) massa e tamanho do bico
sns.scatterplot(x='body_mass_g', y='bill_length_mm', data=df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
# Testar relação (scatterplot / gráfico de dispersão) massa e tamanho do bico
sns.scatterplot(x='body_mass_g', y='bill_length_mm',hue='species', data=df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
# Testar relação (scatterplot / gráfico de dispersão) massa e altura do bico
sns.scatterplot(x='body_mass_g', y='bill_depth_mm', data=df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_depth_mm'>

# %%
# Testar relação (scatterplot / gráfico de dispersão) massa e altura do bico
sns.scatterplot(x='body_mass_g', y='bill_depth_mm',hue='species', data=df)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_depth_mm'>

# %%
# Testar relação (scatterplot / gráfico de dispersão) tamanho da nadadeira e tamanho do bico
sns.scatterplot(x='flipper_length_mm', y='bill_length_mm', data=df)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
# Testar relação (scatterplot / gráfico de dispersão) tamanho da nadadeira e tamanho do bico
sns.scatterplot(x='flipper_length_mm', y='bill_length_mm',hue='island', data=df)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
# Testar relação (scatterplot / gráfico de dispersão) tamanho da nadadeira e altura do bico
sns.scatterplot(x='flipper_length_mm', y='bill_depth_mm', data=df)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# # Correlação de Pearson

# %% [markdown]
# * Esta medida é utilizada para avaliar o relacionamento linear entre duas variáveis contínuas.
# * É adequada quando os dados seguem uma distribuição normal e quando a relação entre as variáveis é linear.
# * A correlação de Pearson varia de -1 a 1, onde -1 indica uma relação negativa perfeita, 0 indica ausência de correlação e 1 indica uma relação positiva perfeita.
# * Por exemplo, você pode usar a correlação de Pearson para investigar a relação entre a altura e o peso das pessoas, pois essas variáveis ​​podem estar linearmente relacionadas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.select_dtypes(include=['float64']).head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 3             NaN            NaN                NaN          NaN
# 4            36.7           19.3              193.0       3450.0

# %%
#criando um novo dataframe só com variáveis quantitativas
df_filter = df.select_dtypes(include=['float64']).copy()

# %%
#correlação pearson
df_filter.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
#mapa de calor com a correlação de pearson
sns.heatmap(df_filter.corr())
# Out:
# <Axes: >

# %% [markdown]
# # Correlação de Spearman

# %% [markdown]
# * Correlação entre variáveis numéricas (lineares ou não) ou entre variáveis qualitativas e quantitativas.
# * Correlação de Spearman é para valores lineares ou não-linerares e para variáveis numéricas ordinais (3 > 2 > 1)
# * Essa medida é uma alternativa à correlação de Pearson quando os dados não seguem uma distribuição normal ou quando há uma relação não linear entre as variáveis.
# * A correlação de Spearman avalia a associação monotônica entre duas variáveis, ou seja, se, quando uma variável aumenta, a outra tende a aumentar ou diminuir consistentemente.
# * Ela não assume a linearidade da relação e é mais robusta a outliers.
# * A correlação de Spearman é calculada a partir das classificações dos dados, ou seja, ela avalia a relação entre as ordens dos dados, não seus valores absolutos.
# *Por exemplo, você pode usar a correlação de Spearman para investigar a relação entre a classificação de desempenho de alunos em dois exames diferentes, onde a relação pode ser monotônica, mas não necessariamente linear.

# %%
df_filter.corr(method='spearman')
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.221749           0.672772
# bill_depth_mm           -0.221749       1.000000          -0.523267
# flipper_length_mm        0.672772      -0.523267           1.000000
# body_mass_g              0.583800      -0.432372           0.839974
#
#                    body_mass_g
# bill_length_mm        0.583800
# bill_depth_mm        -0.432372
# flipper_length_mm     0.839974
# body_mass_g           1.000000

# %%
# Mapa de calor com correlação de spearman
sns.heatmap(df_filter.corr(method='spearman'),cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Variáveis numéricas:
#
# * Se ambas as variáveis forem numéricas e houver suposição de linearidade e distribuição normal, a correlação de Pearson é geralmente a escolha preferida.
# *Se não houver suposição de linearidade ou distribuição normal, ou se os dados forem muito influenciados por outliers, a correlação de Spearman pode ser mais apropriada.
#
# ## Variáveis categóricas:
#
# * Para variáveis categóricas ordinais, a correlação de Spearman é frequentemente utilizada, pois ela considera a ordem dos dados, não os seus valores absolutos.
# * Para variáveis categóricas nominais, outras medidas de associação, como coeficiente de contingência ou teste qui-quadrado, são mais adequadas, pois tanto Pearson quanto Spearman requerem variáveis numéricas.

# %% [markdown]
# # Chi quadrado

# %% [markdown]
# * Mede a relação de dependência entre duas variáveis categóricas, verificando como os valores esperados desviam dos valores observados.
# * Valores altos de Chi-Quadrado indicam variáveis mais dependentes e melhores para serem usadas no modelo.
# * Quando temos um alto valor de Chi-quadrado (nosso p-value será baixo), significa que temos evidência estatística para inferir que os valores observados e esperados não são os mesmos, portanto possuem dependência entre si.

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# retirando os dados nulos do meu dataframe
df_tratado = df.dropna()

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
df_tratado['species'] =  df_tratado.species.map({'Adelie':1,'Chinstrap':2,'Gentoo':3})
df_tratado['island'] =  df_tratado.island.map({'Torgersen':1, 'Biscoe':2, 'Dream':3})
df_tratado['sex'] =  df_tratado.sex.map({'Male':1, 'Female':2})
df_tratado.sample(5)
# Out:
# <ipython-input-86-2e6abe2d3364>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tratado['species'] =  df_tratado.species.map({'Adelie':1,'Chinstrap':2,'Gentoo':3})
# <ipython-input-86-2e6abe2d3364>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tratado['island'] =  df_tratado.island.map({'Torgersen':1, 'Biscoe':2, 'Dream':3})
# <ipython-input-86-2e6abe2d3364>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import sklearn
from sklearn.feature_selection import chi2

# %%
x = df_tratado.drop(['sex', 'bill_length_mm', 'bill_depth_mm','flipper_length_mm','body_mass_g'], axis=1)
y = df_tratado.sex

# %%
#calcular o chi quadrado
chi_scores = chi2(x,y)

#colocar os resultados com o chi² e valor de p
scores = pd.Series(chi_scores[0],index=x.columns)
pvalues = pd.Series(chi_scores[1],index=x.columns)

#resultados
pd.DataFrame({'Chi2':scores, 'p-value':pvalues})
# Out:
#              Chi2   p-value
# species  0.016462  0.897907
# island   0.002332  0.961486

# %% [markdown]
# Como resultado, temos que os **menores Chi2 scores/ maiores p-Values** são os atributos menos dependentes da variável target Sexo.
#
# Portanto, temos que a espécie (species) e a ilha onde habitam (island) são independentes do sexo do animal, não influenciando em uma possível previsão.
# Isso faz todo o sentido, dado que em todas as ilhas e em todas as espécies, teremos os dois sexos de pinguins, sendo muito difícil prever essa variável com apenas essa informação.
